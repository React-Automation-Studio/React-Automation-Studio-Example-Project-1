# %%
# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Set HV On
ser.write(bytearray(p_on_test_params))
# Out:
# 13

# %%
# Set HV On
test = [
    0xA1,
    0x61, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
ser.write(bytearray(test))
# Out:
# 13

# %%
hex(0.1 * 100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
# ----> 1 hex(0.1 * 100)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(hex((0.1 * 100))
# Out:
#   File "<ipython-input-7-c42be226ffd7>", line 1
#     int(hex((0.1 * 100))
#                         ^
# SyntaxError: unexpected EOF while parsing

# %%
int(hex((0.1 * 100)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
# ----> 1 int(hex((0.1 * 100)))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
hex(int((0.1 * 100)))
# Out:
# '0xa'

# %%
bin(0xA1)
# Out:
# '0b10100001'

# %%
bin(0x61)
# Out:
# '0b1100001'

# %%
bin(0xa)
# Out:
# '0b1010'

# %%
bin(0x65)
# Out:
# '0b1100101'

# %%
test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0a,  # Set Voltage
    0x00, 0x65,  # Set Current
    0x00, 0x00,  # Checksum
    0x00, 0x0D,  # EOM
]

# %%
ps_checksum(test)
# Out:
# 12

# %%
hex(12)
# Out:
# '0xc'

# %%
# Set HV On
test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0a,  # Set Voltage
    0x00, 0x65,  # Set Current
    0x00, 0x0C,  # Checksum
    0x00, 0x0D,  # EOM
]
ser.write(bytearray(test))
# Out:
# 13

# %%
res_p_on_test_params = ser.read_until(b'\r')
assert(len(res_p_on_test_params) == 13)

# %%
print("writing")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_1 = ser.read_until(b'\r')

# res_req_params_test_1 = ser.read(len(req_params))
print("Response Length", len(res_req_params_test_1))
assert(len(res_req_params_test_1) == 13)
ser.close()
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# writing
# Reading 13 bytes from Supply
# Response Length 13
# The Serial Port on /dev/ttyUSB0 is open False

# %%
parse_params_response(res_req_params_test_1)
# Out:
# address 161
# command (99, 10)
# status (159, 244)
# voltage (0, 37)
# current (0, 0)
# checksum (0, 23)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 37),
#  (0, 0),
#  (0, 23))

# %%
ser.write(p_off_test_params)
res_p_off_test = ser.read_until(b'\r')
print(res_p_off_test)
# Out:
# ---------------------------------------------------------------------------
# PortNotOpenError                          Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
# ----> <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=185'>186</a> ser.write(p_off_test_params)
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=186'>187</a> res_p_off_test = ser.read_until(b'\r')
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=187'>188</a> print(res_p_off_test)
#
# ~/.local/lib/python3.8/site-packages/serial/serialposix.py in write(self, data)
#     613         """Output the given byte string over the serial port."""
#     614         if not self.is_open:
# --> 615             raise PortNotOpenError()
#     616         d = to_bytes(data)
#     617         tx_len = length = len(d)
#
# PortNotOpenError: Attempting to use a port that is not open

# %%
# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
ser.write(p_off_test_params)
res_p_off_test = ser.read_until(b'\r')
print(res_p_off_test)
# Out:
# b'\xa1b\n\x00\x00\x00\x00\x00\x00\x00\x08\x00\r'

# %%
print("writing")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_off = ser.read_until(b'\r')
# Out:
# writing
# Reading 13 bytes from Supply

# %%
parse_params_response(res_req_params_test_off)
# Out:
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
hex(int((0.1 * 100)))
# Out:
# '0xa'

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0a,  # Set Voltage 100V
    0x00, 0x65,  # Set Current 100mA
    0x00, 0x0C,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0a,  # Set Voltage 100V
    0x00, 0x65,  # Set Current 100mA
    0x00, 0x0C,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}

# %%
# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
ser.write(bytearray(params_list))
res_p_on_test_params = ser.read_until(b'\r')
assert(len(res_p_on_test_params) == 13)

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_1 = ser.read_until(b'\r')
print("Response Length", len(res_req_params_test_1))
assert(len(res_req_params_test_1) == 13)

parse_params_response(res_req_params_test_1)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=159'>160</a> res_req_params_test_1 = ser.read_until(b'\r')
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=160'>161</a> print("Response Length", len(res_req_params_test_1))
# ----> <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=161'>162</a> assert(len(res_req_params_test_1) == 13)
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=162'>163</a>
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=163'>164</a> parse_params_response(res_req_params_test_1)
#
# AssertionError:

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0a,  # Set Voltage 100V
    0x00, 0x65,  # Set Current 100mA
    0x00, 0x0C,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}

# %%
# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_1 = ser.read_until(b'\r')
print("Response Length", len(res_req_params_test_1))
assert(len(res_req_params_test_1) == 13)

parse_params_response(res_req_params_test_1)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=159'>160</a> res_req_params_test_1 = ser.read_until(b'\r')
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=160'>161</a> print("Response Length", len(res_req_params_test_1))
# ----> <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=161'>162</a> assert(len(res_req_params_test_1) == 13)
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=162'>163</a>
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=163'>164</a> parse_params_response(res_req_params_test_1)
#
# AssertionError:

# %%
res_req_params
# Out:
# b'\xa1c\n\xff\xf4\x00\x00\x00\x00\x00\x16\x00\r'

# %%
len(res_req_params)
# Out:
# 13

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=159'>160</a> res_req_params = ser.read_until(b'\r')
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=160'>161</a> print("Response Length", len(res_req_params))
# ----> <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=161'>162</a> assert(len(res_req_params) == 13)
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=162'>163</a>
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=163'>164</a> parse_params_response(res_req_params)
#
# AssertionError:

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0a,  # Set Voltage 100V
    0x00, 0x65,  # Set Current 100mA
    0x00, 0x0C,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=159'>160</a> res_req_params = ser.read_until(b'\r')
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=160'>161</a> print("Response Length", len(res_req_params))
# ----> <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=161'>162</a> assert(len(res_req_params) == 13)
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=162'>163</a>
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=163'>164</a> parse_params_response(res_req_params)
#
# AssertionError:

# %%
ser.close()

# %%
ser.close()
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# The Serial Port on /dev/ttyUSB0 is open False

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0a,  # Set Voltage 100V
    0x00, 0x65,  # Set Current 100mA
    0x00, 0x0C,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=159'>160</a> res_req_params = ser.read_until(b'\r')
#       <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=160'>161</a> print("Response Length", len(res_req_params))
# ----> <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=161'>162</a> assert(len(res_req_params) == 13)
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=162'>163</a>
#      <a href='file:///home/controls/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py?line=163'>164</a> parse_params_response(res_req_params)
#
# AssertionError:

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
# res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 13
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
hex(int(0.1 * 100))
# Out:
# '0xa'

# %%
hex(int(0.1 * 100))
# Out:
# '0xa'

# %%
hex(int(0.11 * 100))
# Out:
# '0xb'

# %%
hex(101)
# Out:
# '0x65'

# %%
hex(int(0.12 * 100))
# Out:
# '0xc'

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0c,  # Set Voltage 120V
    0x00, 0x65,  # Set Current 101mA
    0x00, 0x0C,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
# res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 13
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
print("Testing Power On:")
print("setting HV pin on with 100V and 101mA")
ser.write(p_on_test_params)
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 100V and 101mA
# b''

# %%
p_off_test_cs
# Out:
# 6

# %%
power_on_test
# Out:
# [161, 97, 0, 0, 0, 0, 12, 0, 101, 0, 17, 0, 13]

# %%
chksum
# Out:
# 17

# %%
int(0x0c)
# Out:
# 12

# %%
hex(17)
# Out:
# '0x11'

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0C,  # Set Voltage 120V
    0x00, 0x65,  # Set Current 101mA
    0x00, 0x11,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
print("Testing Power On:")
print("setting HV pin on with 100V and 101mA")
ser.write(p_on_test_params)
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 100V and 101mA
# b''

# %%
ser.close()
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# The Serial Port on /dev/ttyUSB0 is open False

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0C,  # Set Voltage 120V
    0x00, 0x65,  # Set Current 101mA
    0x00, 0x11,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = sum([akum(_) for _ in power_on_test])
power_on_test[10] = chksum
p_on_test_params = serial.to_bytes(power_on_test)
# print(p_on_test_params)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
# res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 13
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
print("Testing Power On:")
print("setting HV pin on with 100V and 101mA")
ser.write(bytearray(p_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 100V and 101mA
# b''

# %%
hex(120)
# Out:
# '0x78'

# %%
hex(0.12 *100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/dev/React-Automation-Studio-Fuse/test_rs485_15kVPS.py in <module>
# ----> 1 hex(0.12 *100)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
hex(int(0.12 *100))
# Out:
# '0xc'

# %%
hex(int(101))
# Out:
# '0x65'

# %%
ps_checksum(power_on_test)
# Out:
# 12

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0C,  # Set Voltage 120V
    0x00, 0x65,  # Set Current 101mA
    0x00, 0x11,  # Checksum
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
chksum = ps_checksum(power_on_test)
power_on_test[10] = chksum
power_on_test_params = serial.to_bytes(power_on_test)
# print(power_on_test)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
# res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 13
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
print("Testing Power On:")
print("setting HV pin on with 100V and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 100V and 101mA
# b'\xa1a\n\x00\x00\x00\x0c\x00e\x00\x0e\x00\r'

# %%
print("Get Parameters after Power On test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_p_on = ser.read_until(b'\r')
parse_params_response(res_req_params_test_p_on)
# P On Test Done
# Out:
# Get Parameters after Power On test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (0, 38)
# current (0, 0)
# checksum (0, 23)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 38),
#  (0, 0),
#  (0, 23))

# %%
print("Testing Power Off")
ser.write(p_off_test_params)
res_p_off_test = ser.read_until(b'\r')
print(res_p_off_test)
# Out:
# Testing Power Off
# b'\xa1b\n\x00\x00\x00\x00\x00\x00\x00\x08\x00\r'

# %%
print("Get Params for power off test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_off = ser.read_until(b'\r')
parse_params_response(res_req_params_test_off)
# Out:
# Get Params for power off test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
print("Get Params for power off test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_off = ser.read_until(b'\r')
parse_params_response(res_req_params_test_off)
# Out:
# Get Params for power off test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
ser.close()
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# The Serial Port on /dev/ttyUSB0 is open False

# %%
hex(100)
# Out:
# '0x64'

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x0C,  # Set Voltage 120V
    0x00, 0x64,  # Set Current 101mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
power_on_test[10] = ps_checksum(power_on_test)
power_on_test_params = serial.to_bytes(power_on_test)
# print(power_on_test)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
# res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 13
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
print("Testing Power Off")
ser.write(p_off_test_params)
res_p_off_test = ser.read_until(b'\r')
print(res_p_off_test)
# Out:
# Testing Power Off
# b'\xa1b\n\x00\x00\x00\x00\x00\x00\x00\x08\x00\r'

# %%
print("Get Params for power off test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_off = ser.read_until(b'\r')
parse_params_response(res_req_params_test_off)
# Out:
# Get Params for power off test
# Reading 13 bytes from Supply
# address 161
# command (98, 10)
# status (0, 0)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 8)
# EOM (0, 13)
# ({'power': 0}, {'hv_over_temp': 0}, (0, 0), (0, 0), (0, 8))

# %%
ser.close()
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# The Serial Port on /dev/ttyUSB0 is open False

# %%
hex(int(.5 * 100))
# Out:
# '0x32'

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x64,  # Set Voltage 500V
    0x00, 0x64,  # Set Current 100mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
power_on_test[10] = ps_checksum(power_on_test)
power_on_test_params = serial.to_bytes(power_on_test)
# print(power_on_test)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
# res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 13
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
print("Testing Power On:")
print("setting HV pin on with 100V and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 100V and 101mA
# b'\xa1a\n\x00\x00\x00d\x00d\x00\x0e\x00\r'

# %%
print("Get Parameters after Power On test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_p_on = ser.read_until(b'\r')
parse_params_response(res_req_params_test_p_on)
# P On Test Done
# Out:
# Get Parameters after Power On test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (0, 104)
# current (0, 0)
# checksum (0, 23)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 104),
#  (0, 0),
#  (0, 23))

# %%
print("Testing Power Off")
ser.write(p_off_test_params)
res_p_off_test = ser.read_until(b'\r')
print(res_p_off_test)
# Out:
# Testing Power Off
# b'\xa1b\n\x00\x00\x00\x00\x00\x00\x00\x08\x00\r'

# %%
import serial
# import serial.rs485
from serial.serialutil import to_bytes


def to_hex(value: int, size=4):
    return "{0:#0{1}x}".format(value, size)


def akum(value):
    return sum([int(i) for i in bin(value)[2:]])


def ps_checksum(data):
    return sum([akum(_) for _ in data[:9]])


def parse_params_response(res):
    status0_lables = [
        'power',
        'hv_on',
        'const_hv',
        'const_ma',
        'const_pow',
        'over_volt',
        'inv_over_cur',
        'inv_over_temp'
    ]
    status1_labels = [
        'hv_over_temp',
        'spark',
        'ac_fault',
        'emergency',
        'interlock',
        '485/plc',
        'NA1',
        'NA2'
    ]
    tmp = [x for x in res]
    address = tmp[0]
    print("address", address)
    command = tmp[1], tmp[2]
    print("command", command)
    status = tmp[3], tmp[4]
    print("status", status)
    V = tmp[5], tmp[6]
    print("voltage", V)
    I = tmp[7], tmp[8]
    print("current", I)
    checksum = tmp[9], tmp[10]
    print("checksum", checksum)
    eom = tmp[11], tmp[12]
    print("EOM", eom)

    status_dict = {0: dict(zip(status0_lables, [int(i) for i in bin(status[0])[2:]])),
                   1: dict(zip(status1_labels, [int(i) for i in bin(status[1])[2:]]))}
    return status_dict[0], status_dict[1], V, I, checksum

# %%
# Setting some commands and serial settings
params_list = [
    0xA1,
    0x63, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x07,
    0x00, 0x0D
]

req_params = serial.to_bytes(params_list)

res_req_params_good = params_list[:]
res_req_params_good[2] = 0x0A
# res_req_params_cs = sum([akum(_) for _ in params_list][:9])
res_req_params_cs = ps_checksum(req_params)
res_req_params_good[10] = res_req_params_cs
# print(res_req_params_good)
res_req_params_good = to_bytes(res_req_params_good)
# print(res_req_params_good)


# Set HV Pin: charge: 1.1kV and 101mA
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0x64,  # Set Voltage 500V
    0x00, 0x64,  # Set Current 100mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
power_on_test[10] = ps_checksum(power_on_test)
power_on_test_params = serial.to_bytes(power_on_test)
# print(power_on_test)

# Good response to check against
p_on_test_good = power_on_test[:]
p_on_test_good[2] = 0x0A
p_on_test_good = serial.to_bytes(p_on_test_good)
# print("p on test good resp", p_on_test_good)
assert(len(power_on_test) == 13)

# Turn HV pin off values
p_off_test_list = [
    0xA1,
    0x62, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x00,
    0x00, 0x0D
]
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)
p_off_test_params = serial.to_bytes(p_off_test_list)
# print(p_off_test_cs)

# Good HV pin off value
p_off_test_good = p_off_test_list[:]
p_off_test_good[2] = 0x0A
# p_off_test_good_cs = sum([akum(_) for _ in p_off_test_params][:9])
p_off_test_good_cs = ps_checksum(p_off_test_params)
p_off_test_good[10] = p_off_test_good_cs
# print("good resp p off test", p_off_test_good)
p_off_test_good = serial.to_bytes(p_off_test_good)

port = "/dev/ttyUSB0"

settings = {
    "port": "/dev/ttyUSB0",
    "baudrate": 38400,
    "parity": serial.PARITY_NONE,
    "stopbits": serial.STOPBITS_ONE,
    "bytesize": serial.EIGHTBITS,
    "timeout": 1,
}


# Opening serial connection
print("Opening serial connection on port: {}".format(port))

ser = serial.Serial(**settings)
print("The Serial Port on {} is open {}".format(port, ser.is_open))
# Out:
# Opening serial connection on port: /dev/ttyUSB0
# The Serial Port on /dev/ttyUSB0 is open True

# %%
# Get Params first
print("Test Getting System Parameters on Startup")
ser.write(bytearray(params_list))
res_req_params = ser.read_until(b'\r')
assert(len(res_req_params) == 13)
print("Reading {} bytes from Supply".format(len(params_list)))
# res_req_params = ser.read_until(b'\r')
print("Response Length", len(res_req_params))
assert(len(res_req_params) == 13)

parse_params_response(res_req_params)
# Out:
# Test Getting System Parameters on Startup
# Reading 13 bytes from Supply
# Response Length 13
# address 161
# command (99, 10)
# status (255, 244)
# voltage (0, 0)
# current (0, 0)
# checksum (0, 22)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 1,
#   'const_hv': 1,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 0),
#  (0, 0),
#  (0, 22))

# %%
print("Testing Power On:")
print("setting HV pin on with 100V and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 100V and 101mA
# b'\xa1a\n\x00\x00\x00d\x00d\x00\x0e\x00\r'

# %%
print("Get Parameters after Power On test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_p_on = ser.read_until(b'\r')
parse_params_response(res_req_params_test_p_on)
# P On Test Done
# Out:
# Get Parameters after Power On test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (0, 104)
# current (0, 0)
# checksum (0, 23)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 104),
#  (0, 0),
#  (0, 23))

# %%
hex(200)
# Out:
# '0xc8'

# %%
print("Testing Power On:")
print("setting HV pin on with 2kV and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 2kV and 101mA
# b'\xa1a\n\x00\x00\x00d\x00d\x00\x0e\x00\r'

# %%
print("Testing Power Off")
ser.write(p_off_test_params)
res_p_off_test = ser.read_until(b'\r')
print(res_p_off_test)
# Out:
# Testing Power Off
# b'\xa1b\n\x00\x00\x00\x00\x00\x00\x00\x08\x00\r'

# %%
print("Testing Power On:")
print("setting HV pin on with 100V and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)
# Out:
# Testing Power On:
# setting HV pin on with 100V and 101mA
# b'\xa1a\n\x00\x00\x00d\x00d\x00\x0e\x00\r'

# %%
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0xc8,  # Set Voltage 2kV 0xc8
    0x00, 0x64,  # Set Current 100mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

# %%
p_off_test_cs = ps_checksum(p_off_test_list)
p_off_test_list[10] = p_off_test_cs
# print("p off test", p_off_test_list)

p_off_test_params = serial.to_bytes(p_off_test_list)

# %%
print("Testing Power On:")
print("setting HV pin on with 2kV and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)

print("Get Parameters after Power On test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_p_on = ser.read_until(b'\r')
parse_params_response(res_req_params_test_p_on)
# P On Test Done
# Out:
# Testing Power On:
# setting HV pin on with 2kV and 101mA
# b'\xa1a\n\x00\x00\x00d\x00d\x00\x0e\x00\r'
# Get Parameters after Power On test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (0, 104)
# current (0, 0)
# checksum (0, 23)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 104),
#  (0, 0),
#  (0, 23))

# %%
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x00, 0xc8,  # Set Voltage 2kV 0xc8
    0x00, 0x64,  # Set Current 100mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
power_on_test[10] = ps_checksum(power_on_test)
power_on_test_params = serial.to_bytes(power_on_test)

# %%
power_on_test_params
# Out:
# b'\xa1a\x00\x00\x00\x00\xc8\x00d\x00\x0c\x00\r'

# %%
print("Testing Power On:")
print("setting HV pin on with 2kV and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)

print("Get Parameters after Power On test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_p_on = ser.read_until(b'\r')
parse_params_response(res_req_params_test_p_on)
# P On Test Done
# Out:
# Testing Power On:
# setting HV pin on with 2kV and 101mA
# b'\xa1a\n\x00\x00\x00\xc8\x00d\x00\x0e\x00\r'
# Get Parameters after Power On test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (0, 104)
# current (0, 0)
# checksum (0, 23)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 104),
#  (0, 0),
#  (0, 23))

# %%
hex(300)
# Out:
# '0x12c'

# %%
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x01, 0x2c,  # Set Voltage 2kV 0xc8
    0x00, 0x64,  # Set Current 100mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
power_on_test[10] = ps_checksum(power_on_test)
power_on_test_params = serial.to_bytes(power_on_test)

# %%
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x01, 0x2c,  # Set Voltage 2kV 0xc8
    0x00, 0x64,  # Set Current 100mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
power_on_test[10] = ps_checksum(power_on_test)
power_on_test_params = serial.to_bytes(power_on_test)

# %%
print("Testing Power On:")
print("setting HV pin on with 2kV and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)

print("Get Parameters after Power On test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_p_on = ser.read_until(b'\r')
parse_params_response(res_req_params_test_p_on)
# P On Test Done
# Out:
# Testing Power On:
# setting HV pin on with 2kV and 101mA
# b'\xa1a\n\x00\x00\x01,\x00d\x00\x0f\x00\r'
# Get Parameters after Power On test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (0, 203)
# current (0, 0)
# checksum (0, 25)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (0, 203),
#  (0, 0),
#  (0, 25))

# %%
hex(900)
# Out:
# '0x384'

# %%
power_on_test = [
    0xA1,
    0x61, 0x00,  # co mmand
    0x00, 0x00,  # Header
    0x03, 0x84,  # Set Voltage 2kV 0xc8
    0x00, 0x64,  # Set Current 100mA
    0x00, 0x00,  # Checksum computed before sending
    0x00, 0x0D,  # EOM
]

chksum_po = map(bin, power_on_test[:9])
power_on_test[10] = ps_checksum(power_on_test)
power_on_test_params = serial.to_bytes(power_on_test)

# %%
print("Testing Power On:")
print("setting HV pin on with 2kV and 101mA")
ser.write(bytearray(power_on_test_params))
res_p_on_test = ser.read_until(b'\r')
print(res_p_on_test)

print("Get Parameters after Power On test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_p_on = ser.read_until(b'\r')
parse_params_response(res_req_params_test_p_on)
# P On Test Done
# Out:
# Testing Power On:
# setting HV pin on with 2kV and 101mA
# b'\xa1a\n\x00\x00\x03\x84\x00d\x00\x0f\x00\r'
# Get Parameters after Power On test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (1, 47)
# current (0, 0)
# checksum (0, 26)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (1, 47),
#  (0, 0),
#  (0, 26))

# %%
print("Testing Power Off")
ser.write(p_off_test_params)
res_p_off_test = ser.read_until(b'\r')
print(res_p_off_test)

print("Get Params for power off test")
ser.write(bytearray(params_list))
print("Reading {} bytes from Supply".format(len(params_list)))
res_req_params_test_off = ser.read_until(b'\r')
parse_params_response(res_req_params_test_off)
# Out:
# Testing Power Off
# b'\xa1b\n\x00\x00\x00\x00\x00\x00\x00\x08\x00\r'
# Get Params for power off test
# Reading 13 bytes from Supply
# address 161
# command (99, 10)
# status (159, 244)
# voltage (3, 133)
# current (0, 0)
# checksum (0, 25)
# EOM (0, 13)
# ({'power': 1,
#   'hv_on': 0,
#   'const_hv': 0,
#   'const_ma': 1,
#   'const_pow': 1,
#   'over_volt': 1,
#   'inv_over_cur': 1,
#   'inv_over_temp': 1},
#  {'hv_over_temp': 1,
#   'spark': 1,
#   'ac_fault': 1,
#   'emergency': 1,
#   'interlock': 0,
#   '485/plc': 1,
#   'NA1': 0,
#   'NA2': 0},
#  (3, 133),
#  (0, 0),
#  (0, 25))
